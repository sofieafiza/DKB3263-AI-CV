# %% [markdown]
# <a href="https://colab.research.google.com/github/sofieafiza/DKB3263-AI-CV/blob/main/obj_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
camera=cv2.VideoCapture(0)
while true;
success,frame= camera.read()
cv2.imshow("Webcam",frame)
if cv2.waitkey(1)== ord('q'):
camera.release()
cv2.destroyAllWindows()
